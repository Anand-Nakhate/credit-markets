# %% [markdown]
# # Homework 3
#
# ## FINM 35700 - Spring 2025
#
# ### UChicago Financial Mathematics
#
# ### Due Date: 2025-04-14
#
# * Alex Popovici
# * alex.popovici@uchicago.edu

# %% [markdown]
# This homework relies on:
#
# - the corporate and government bonds symbology file `bond_symbology`,
# - the "on-the-run" treasuries data file `govt_on_the_run`,
# - the bond market data file `bond_market_prices_eod`, containing EOD price data as of 2024-12-13.
# - the corporate bonds call schedule file `call_schedules`.

# %% [markdown]
# -----------------------------------------------------------
# # Problem 1: Different types of bond yields and durations (fixed income recap)
#
# ### A. Continuously compounded (exponential) yields
# In Lecture 1 we introduced the continuously compounded (exponential) yield $y$, used to discount bonds with arbitrary/generic cashflows
#
# \begin{align}
# \{c_i ,T_i\}_{i=1..n}
# \end{align}
#
# via the valuation formula
#
# \begin{align}
# B(y)=\sum_{i=1}^{n}c_{i}\cdot e^{-T_{i}\cdot y}
# \end{align}
#
# We then defined the bond duration $D$ (also called Macaulay duration) as the log-sensitivity of the bond price with respect to the exponential yield $y$:
#
# \begin{align}
# \frac{\partial B}{\partial y} = -B \cdot D
# \end{align}
#
# and showed that $D$ can be expressed as a weighted sum of time to maturities $T_i$
#
# \begin{align}
# D=\frac{\sum_{i=1}^{n}T_i \cdot c_{i}\cdot e^{-T_{i}\cdot y}}{\sum_{i=1}^{n}c_{i}\cdot e^{-T_{i}\cdot y}} = \sum_{i=1}^{n}T_i \cdot w_i
# \end{align}
#
# ### B. Discretely compounded yields
# For bonds with n regular coupon payment (coupon frequency = n), it is natural to define the discretely compounded yields $y_n$ (corresponding to the coupon frequency n):
#
#
# \begin{align}
# \left(1+\frac{y_{n}}{n}\right)^n=e^y
# \end{align}
#
# The most common cases in US fixed income markets are:
#
# 1. Semi-annual coupon frequency (e.g fixed rate USD bonds): the semi-annual yield $y_{sa} = y_2$ satisfies the formula
#
# \begin{align}
# \left(1+\frac{y_{sa}}{2}\right)^2=e^y
# \end{align}
#
# 2. Quarterly coupon frequency (e.g floating rate USD bonds): the quarterly yield $y_{qt} = y_4$ satisfies the formula
#
# \begin{align}
# \left(1+\frac{y_{qt}}{4}\right)^4=e^y
# \end{align}
#
#
# 3. Monthly coupon frequency (e.g USD loans): the monthly yield $y_{mo} = y_{12}$ satisfies the formula
#
# \begin{align}
# \left(1+\frac{y_{mo}}{12}\right)^{12}=e^y
# \end{align}
#
# As a general rule, discretely compunded yields are descreasing in the coupon frequency n:
#
# \begin{align}
# y_{sa} \geq y_{qt} \geq y_{mo} \geq y_{\infty} = y
# \end{align}
#
# ### C. Modified duration
# For a bond with n regular coupon payments, the modified duration $D_{mod}$ is defined as the log-sensitivity of the bond price with respect to the discretely compounded yield $y_n$:
#
# \begin{align}
# \frac{\partial B}{\partial y_{n}} = -B \cdot D_{mod}
# \end{align}
#
#
# In practice, when fixed income market participants talk about yields, DV01s and durations, they imply the type based on the cashflow frequency of the underlying instrument.
#
# ## To do:

# %% [markdown]
# ### a. For fixed rate semi-annual USD bonds (frequency = 2), show that
#
# \begin{align}
# D_{mod} = D \cdot \left(1+\frac{y_{sa}}{2} \right)^{-1}
# \end{align}

# %% [markdown]
# ![image.png](attachment:4663cc98-c463-4ce8-aeb9-70e39116bb13.png)

# %% [markdown]
# ### b. In general, for bonds with n regular coupon payments (frequency = n), show that
#
# \begin{align}
# D_{mod} = D \cdot \left(1+\frac{y_{n}}{n} \right)^{-1}
# \end{align}

# %% [markdown]
# ![image.png](attachment:15c4ce1e-e2cc-4cd9-adc7-70541c39a9bd.png)

# %% [markdown]
# -----------------------------------------------------------
# # Problem 2: Callable bonds: "workout-date" and "yield-to-worst" calculations

# %%
import QuantLib as ql
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

# import tools from previous homeworks
from credit_market_tools import *

# Use static calculation/valuation date of 2024-12-13, matching data available in the market prices EOD file
calc_date = ql.Date(13, 12, 2024)
ql.Settings.instance().evaluationDate = calc_date

# %% [markdown]
# ## a. Load and explore the call schedules dataframe
#
# Load the `call_schedules` Excel file into a dataframe. It contains call schedules for fixed-rate, callable corporate bonds.
#
# For each bond in the dataframe, compute `num_call_dates`, the total number of outstanding calls.

# %%
call_schedules_df = pd.read_excel("data/call_schedules.xlsx")
grp = call_schedules_df.groupby('isin').size().reset_index(name='num_call_dates')
call_schedules_df = pd.merge(call_schedules_df, grp, on='isin', how='left')
display(call_schedules_df)
# Out:
#               isin          figi  call_date  call_price  num_call_dates
# 0     US345397D427  BBG01GXL4DP0 2030-03-10         100               1
# 1     US345397D591  BBG01K0V0QY0 2028-10-07         100               1
# 2     US345397E748  BBG01MVPX165 2027-04-17         100               1
# 3     US345397G313  BBG01QLGYZV3 2031-09-05         100               1
# 4     US34540TB359  BBG019LXFLX4 2026-03-20         100              13
# ...            ...           ...        ...         ...             ...
# 4445  US61747YFT73  BBG01NTC30T5 2035-07-14         100              92
# 4446  US61747YFT73  BBG01NTC30T5 2035-07-15         100              92
# 4447  US61747YFT73  BBG01NTC30T5 2035-07-16         100              92
# 4448  US61747YFT73  BBG01NTC30T5 2035-07-17         100              92
# 4449  US61747YFT73  BBG01NTC30T5 2035-07-18         100              92
#
# [4450 rows x 5 columns]

# %% [markdown]
# ## b. Load the bond symbology dataframe and extend it with the fixed-rate callable corporate bond details from 1a.
#
# Load the `bond_symbology` Excel file into a dataframe and keep only the fixed-rate callable bonds from 1a.
#
# Extend the dataframe with the column computed in 1a:
#
# | num_call_dates |
# |----------|

# %%
bond_symbology_df = pd.read_excel("data/bond_symbology.xlsx")
bond_symbology_df = bond_symbology_df[bond_symbology_df['cpn_type']=='FIXED']
bond_symbology_df = bond_symbology_df[bond_symbology_df['isin'].isin(call_schedules_df['isin'].unique())]
bond_symbology_df = pd.merge(bond_symbology_df, grp, on='isin', how='left')
bond_symbology_df
# Out:
#    ticker class          figi          isin und_bench_isin  \
# 0    AAPL  Corp  BBG00C7QBCQ1  US037833BW97   US91282CLW90
# 1    AAPL  Corp  BBG00C7QBG91  US037833BX70   US912810UF39
# 2    AAPL  Corp  BBG00DHQX240  US037833BZ29   US91282CLY56
# 3    AAPL  Corp  BBG00DHQX9M5  US037833CD08   US912810UF39
# 4    AAPL  Corp  BBG00FXTS8Z0  US037833CJ77   US91282CMB45
# ..    ...   ...           ...           ...            ...
# 90   ORCL  Corp  BBG01DZ9FPY3  US68389XCQ60   US912810UC08
# 91   ORCL  Corp  BBG01Q0P7VR0  US68389XCS27   US91282CMA61
# 92   ORCL  Corp  BBG01Q0P7W61  US68389XCT00   US91282CLW90
# 93   ORCL  Corp  BBG01Q0P7WR8  US68389XCU72   US912810UC08
# 94   ORCL  Corp  BBG01Q0P7XC2  US68389XCV55   US912810UC08
#
#                security         name    type  coupon cpn_type  ...  cpn_first  \
# 0   AAPL 4 1/2 02/23/36    APPLE INC  GLOBAL   4.500    FIXED  ... 2016-08-23
# 1    AAPL 4.65 02/23/46    APPLE INC  GLOBAL   4.650    FIXED  ... 2016-08-23
# 2    AAPL 2.45 08/04/26    APPLE INC  GLOBAL   2.450    FIXED  ... 2017-02-04
# 3    AAPL 3.85 08/04/46    APPLE INC  GLOBAL   3.850    FIXED  ... 2017-02-04
# 4    AAPL 3.35 02/09/27    APPLE INC  GLOBAL   3.350    FIXED  ... 2017-08-09
# ..                  ...          ...     ...     ...      ...  ...        ...
# 90   ORCL 5.55 02/06/53  ORACLE CORP  GLOBAL   5.550    FIXED  ... 2023-08-06
# 91    ORCL 4.2 09/27/29  ORACLE CORP  GLOBAL   4.200    FIXED  ... 2025-03-27
# 92    ORCL 4.7 09/27/34  ORACLE CORP  GLOBAL   4.700    FIXED  ... 2025-03-27
# 93  ORCL 5 3/8 09/27/54  ORACLE CORP  GLOBAL   5.375    FIXED  ... 2025-03-27
# 94  ORCL 5 1/2 09/27/64  ORACLE CORP  GLOBAL   5.500    FIXED  ... 2025-03-27
#
#     acc_first   maturity   mty_typ          rank amt_out country currency  \
# 0  2016-02-23 2036-02-23  CALLABLE  Sr Unsecured  1250.0      US      USD
# 1  2016-02-23 2046-02-23  CALLABLE  Sr Unsecured  4000.0      US      USD
# 2  2016-08-04 2026-08-04  CALLABLE  Sr Unsecured  2250.0      US      USD
# 3  2016-08-04 2046-08-04  CALLABLE  Sr Unsecured  2000.0      US      USD
# 4  2017-02-09 2027-02-09  CALLABLE  Sr Unsecured  2250.0      US      USD
# ..        ...        ...       ...           ...     ...     ...      ...
# 90 2023-02-06 2053-02-06  CALLABLE  Sr Unsecured  2250.0      US      USD
# 91 2024-09-27 2029-09-27  CALLABLE  Sr Unsecured  1500.0      US      USD
# 92 2024-09-27 2034-09-27  CALLABLE  Sr Unsecured  1750.0      US      USD
# 93 2024-09-27 2054-09-27  CALLABLE  Sr Unsecured  1750.0      US      USD
# 94 2024-09-27 2064-09-27  CALLABLE  Sr Unsecured  1250.0      US      USD
#
#    status  num_call_dates
# 0    ACTV               1
# 1    ACTV               1
# 2    ACTV               1
# 3    ACTV               1
# 4    ACTV               1
# ..    ...             ...
# 90   ACTV               1
# 91   ACTV               1
# 92   ACTV               1
# 93   ACTV               1
# 94   ACTV               1
#
# [95 rows x 24 columns]

# %% [markdown]
# ## c. Add a function to compute "yield-to-maturity",  "yield-to-worst" and "workout date" for a fixed-rate callable bond
#
# Quick recap: given the current market price, the issuer is expected to call a callable bond on the call date corresponding to lowes "yield to call date".
#
# This corresponds to the best possible scenario from the point of view of the issuer exercising the call option (and the worst possible scenario from the point of view of the bond investor).
#
# The lowest possible yield on a call date is called the "yield-to-worst" and the corresponding call date (on which the issuer is expected to call the bond) is called the "workout date".
#
# Keep in mind that the "workout date" could be the bond maturity date, in which case "yield-to-worst" = "yield-to-maturity".
#
# To do: for a callable fixed-rate bond with known symbology (reference data) and call schedules dataframes, create a function that takes the clean market price as an input and returns the "yield-to-maturity, "yield-to-worst and "workout date".
#
# 1. Compute the yield to maturrity first.
# 2. For each  call date, create the corresponding "call scenario" bond object (using the call date as maturity).
# 3. Compute the corresponding "call scenario yield" (using the bond clean market price as input).
# 4. Identify "workout date" and "yield-to-worst".

# %%
def create_call_scenario_bond(details, call_date, call_price):
    d = details.copy()
    if isinstance(call_date, ql.Date):
        d["maturity"] = call_date.ISO()
    else:
        t = pd.to_datetime(call_date)
        d["maturity"] = t.strftime("%Y-%m-%d")
    d["redemption"] = call_price
    return create_bond_from_symbology(d)

def calc_yield_to_worst(details, pc_schedule, bond_clean_price, calc_date):
    ql.Settings.instance().evaluationDate = calc_date
    b = create_bond_from_symbology(details)
    dc = b.dayCounter()
    c = ql.Compounded
    f = ql.Semiannual
    ytm = b.bondYield(bond_clean_price, dc, c, f)
    scenarios = [(b.maturityDate(), ytm)]
    subset = pc_schedule[pc_schedule["isin"] == details["isin"]]
    for _, row in subset.iterrows():
        d = row["call_date"]
        if not isinstance(d, ql.Date):
            x = pd.to_datetime(d)
            d = ql.Date(x.day, x.month, x.year)
        if d < calc_date or d > b.maturityDate():
            continue
        cp = float(row["call_price"])
        scb = create_call_scenario_bond(details, d, cp)
        y = scb.bondYield(bond_clean_price, scb.dayCounter(), c, f)
        scenarios.append((d, y))
    w = min(scenarios, key=lambda x: x[1])
    return w[0], w[1]

# %% [markdown]
# ## d. Compute "workout dates" and "yields-to-worst" for all Oracle fixed-rate callable bonds
#
# Load the `bond_market_prices_eod` Excel file into a dataframe, which contains marktet quotes as of 2024-12-13.
#
# For each Oracle fixed-rate callable bond in the symbology dataframe (ticker = 'ORCL'):
# - 1. Compute the yield to maturity (using clean market prices)
#
# - 2. Use the function from 1c to compute "workout date" and "yield-to-worst".
#
# Extend the symbology dataframe with the following columns:
#
#
# | clean_price |  yield_to_maturity | yield_to_worst | workout_date |
# |----------|-------------|-------|-------------|
#
# Which ORCL callable bonds are expected to be called early, i.e. have workout_date < maturity? There should be 3 of them!

# %%
bond_market_prices_eod_df = pd.read_excel("data/bond_market_prices_eod.xlsx")
bond_market_prices_eod_df['midPrice'] = (bond_market_prices_eod_df['bidPrice'] + bond_market_prices_eod_df['askPrice'])*0.5

orcl_symbology = bond_symbology_df[bond_symbology_df['ticker']=='ORCL']
orcl_mkt = bond_market_prices_eod_df[(bond_market_prices_eod_df['ticker']=='ORCL') & (bond_market_prices_eod_df['date']=='2024-12-13')]

res = []
for _, r in orcl_symbology.iterrows():
    p = float(orcl_mkt[orcl_mkt['isin']==r['isin']]['midPrice'].iloc[0])
    b = create_bond_from_symbology(r)
    ytm = ql.BondFunctions.bondYield(b, p, b.dayCounter(), ql.Compounded, ql.Semiannual)
    wdate, ytw = calc_yield_to_worst(r, call_schedules_df, p, ql.Date(13,12,2024))
    res.append({
        'isin': r['isin'],
        'clean_price': p,
        'yield_to_maturity': ytm,
        'yield_to_worst': ytw,
        'workout_date': wdate,
        'maturity': b.maturityDate()
    })
final_df = pd.DataFrame(res)
called_early_df = final_df[final_df['workout_date'] < final_df['maturity']]

# %%
called_early_df
# Out:
#             isin  clean_price  yield_to_maturity  yield_to_worst  \
# 23  US68389XCH61     105.4465           0.048847        0.048456
# 24  US68389XCJ28     107.1520           0.051359        0.051072
# 25  US68389XCK90     114.2355           0.058574        0.058505
#
#            workout_date            maturity
# 23  September 9th, 2029  November 9th, 2029
# 24     August 9th, 2032  November 9th, 2032
# 25        May 9th, 2052  November 9th, 2052

# %% [markdown]
# -----------------------------------------------------------
# # Problem 3: Risk & Scenario analysis for a fixed rate corporate bond (yield model)
# ## Use the QuantLib Basic notebook (or previous homeworks) as templates.

# %% [markdown]
# ## a. Create generic fixed-rate corporate bond
# Fix the calculation date as of December 13 2024 and use a coupon of 5% and a maturity of 10 years (December 13 2034).
#
# Display the fixed rate bond cashflows.

# %%
# import tools from previous homeworks
from credit_market_tools import *

# Use static calculation/valuation date of 2024-12-13, matching data available in the market prices EOD file
calc_date = ql.Date(13, 12, 2024)
ql.Settings.instance().evaluationDate = calc_date

# %%
ql.Settings.instance().evaluationDate = ql.Date(13, 12, 2024)
test_bond_details = {
    'class': 'Corp',
    'start_date': '2024-12-13',
    'acc_first': '2024-12-13',
    'maturity': '2034-12-13',
    'coupon': 5,
    'dcc': '30/360',
    'days_settle': 1
}

bond_10yr = create_bond_from_symbology(test_bond_details)
cf_10yr = get_bond_cashflows(bond_10yr, ql.Date(13, 12, 2024))
display(cf_10yr)
# Out:
#            CashFlowDate  CashFlowYearFrac  CashFlowAmount
# 0       June 13th, 2025               0.5             2.5
# 1   December 13th, 2025               1.0             2.5
# 2       June 13th, 2026               1.5             2.5
# 3   December 13th, 2026               2.0             2.5
# 4       June 13th, 2027               2.5             2.5
# 5   December 13th, 2027               3.0             2.5
# 6       June 13th, 2028               3.5             2.5
# 7   December 13th, 2028               4.0             2.5
# 8       June 13th, 2029               4.5             2.5
# 9   December 13th, 2029               5.0             2.5
# 10      June 13th, 2030               5.5             2.5
# 11  December 13th, 2030               6.0             2.5
# 12      June 13th, 2031               6.5             2.5
# 13  December 13th, 2031               7.0             2.5
# 14      June 13th, 2032               7.5             2.5
# 15  December 13th, 2032               8.0             2.5
# 16      June 13th, 2033               8.5             2.5
# 17  December 13th, 2033               9.0             2.5
# 18      June 13th, 2034               9.5             2.5
# 19  December 13th, 2034              10.0             2.5
# 20  December 13th, 2034              10.0           100.0

# %% [markdown]
# ## b. Compute the bond price, DV01, duration and convexity (analytic method).
#
# Assume that the market yield of the bond is 6%. Compute the bond price, DV01, duration and convexity, using the analytic method.

# %%
day_count = bond_10yr.dayCounter()
freq = ql.Semiannual
compounding = ql.Compounded
yld = 0.06
px = ql.BondFunctions.cleanPrice(bond_10yr, yld, day_count, compounding, freq)
r = ql.InterestRate(yld, day_count, compounding, freq)
dur = ql.BondFunctions.duration(bond_10yr, r, ql.Duration.Modified)
cnv = ql.BondFunctions.convexity(bond_10yr, r)
dv01 = dur * px * 1e-4

bond_metrics = {
    'CleanPrice_6pct': px,
    'DV01_6pct': dv01,
    'Duration_6pct': dur,
    'Convexity_6pct': cnv
}
for k, v in bond_metrics.items():
    print(f"{k}: {v}")
# Out:
# CleanPrice_6pct: 92.56520713822074
# DV01_6pct: 0.07087676576927465
# Duration_6pct: 7.656955346455353
# Convexity_6pct: 71.65750611807

# %% [markdown]
# ## c. Scenario bond prices: "re-pricing" vs "second-order approximations"
#
# Compute the scenario bond prices on the following scenario yield grid: [from 1% to 11% in steps of 0.5%]
#
# Compute the second-order scenario price approximations using duration and convexity sensitivities (formula 13 from Lecture 1).
#
# \begin{align}
# \Delta B(y) = B\left(y+\Delta y\right)-B\left(y\right)\approx B\cdot\left[- D\cdot\Delta y+\frac{1}{2}\cdot\Gamma\cdot\left(\Delta y\right)^{2}\right]
# \end{align}
#
# Plot the scenario prices (Y-axis) vs yieds (X-axis), for both the "re-pricing" and "second-order approximations" method.

# %%
scenario_yields = np.arange(0.01, 0.115, 0.005)
base_price = px
base_yield = yld
base_dur = dur
base_cnv = cnv

reprice_list = []
approx_list = []
for sy in scenario_yields:
    sp = ql.BondFunctions.cleanPrice(bond_10yr, sy, day_count, compounding, freq)
    dy = sy - base_yield
    delta_b_approx = -base_dur * base_price * dy + 0.5 * base_cnv * base_price * (dy**2)
    approx_p = base_price + delta_b_approx
    reprice_list.append(sp)
    approx_list.append(approx_p)

scenario_df = pd.DataFrame({'Yield': scenario_yields, 'Repriced': reprice_list, 'Approx2': approx_list})
display(scenario_df)
# Out:
#     Yield    Repriced     Approx2
# 0   0.010  137.944641  136.294830
# 1   0.015  132.363856  131.175656
# 2   0.020  127.047737  126.222307
# 3   0.025  121.982740  121.434783
# 4   0.030  117.156050  116.813083
# 5   0.035  112.555546  112.357209
# 6   0.040  108.169759  108.067159
# 7   0.045  103.987833  103.942934
# 8   0.050   99.999496   99.984533
# 9   0.055   96.195023   96.191958
# 10  0.060   92.565207   92.565207
# 11  0.065   89.101329   89.104281
# 12  0.070   85.795131   85.809180
# 13  0.075   82.638792   82.679904
# 14  0.080   79.624903   79.716452
# 15  0.085   76.746442   76.918826
# 16  0.090   73.996756   74.287024
# 17  0.095   71.369539   71.821047
# 18  0.100   68.858812   69.520894
# 19  0.105   66.458909   67.386567
# 20  0.110   64.164454   65.418064

# %%
plt.figure(figsize=(10,6))
plt.plot(scenario_df['Yield']*100, scenario_df['Repriced'], marker='o', label='Repriced')
plt.plot(scenario_df['Yield']*100, scenario_df['Approx2'], marker='x', label='2nd-Order Approx')
plt.xlabel('Yield (%)')
plt.ylabel('Price')
plt.title('Scenario Bond Prices: Re-Pricing vs 2nd-Order Approx')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## d. Extreme event scenarios
#
# Compute and show the scenario bond price for a bond yield of 15% (extreme event scenario).
#
# Compute and show the second-order scenario price approximation in the extreme event scenario.
#
# Compute and show the analytic DV01, duration and convexity in the extreme event scenario.
#
# How accurate is the second-order approximation (Taylor expansion using duration and convexity) in the extreme event case, and why?

# %%
extreme_yield = 0.15
extreme_price = ql.BondFunctions.cleanPrice(bond_10yr, extreme_yield, day_count, compounding, freq)
dy_extreme = extreme_yield - base_yield
approx_extreme = base_price + (-base_dur * base_price * dy_extreme + 0.5 * base_cnv * base_price * (dy_extreme**2))
r_extreme = ql.InterestRate(extreme_yield, day_count, compounding, freq)
dur_extreme = ql.BondFunctions.duration(bond_10yr, r_extreme, ql.Duration.Modified)
cnv_extreme = ql.BondFunctions.convexity(bond_10yr, r_extreme)
dv01_extreme = dur_extreme * extreme_price * 1e-4

extreme_results = {
    'Yield_15pct_Price': extreme_price,
    '2nd_Order_Approx_Price': approx_extreme,
    'DV01_15pct': dv01_extreme,
    'Duration_15pct': dur_extreme,
    'Convexity_15pct': cnv_extreme,
    'Approx_Error': extreme_price - approx_extreme
}

for k, v in extreme_results.items():
    print(f"{k}: {v}")
# Out:
# Yield_15pct_Price: 49.04500723931266
# 2nd_Order_Approx_Price: 55.63973512802481
# DV01_15pct: 0.031563317203875584
# Duration_15pct: 6.435582127629007
# Convexity_15pct: 55.33749443292361
# Approx_Error: -6.59472788871215

# %% [markdown]
# For large yield changes, higher-order effects cause the second-order approximation to deviate significantly from the full repricing. Duration–convexity captures only local curvature, so a simple Taylor expansion around 6% is less accurate when yields jump to 15%.

# %% [markdown]
# -----------------------------------------------------------
# # Problem 4: Perpetual bonds
# ## a. Price a fixed rate perpetual bond
# We are interested in a fixed rate perpetual bond (infinite maturity) on a face notional of $100 and semi-annual coupon c.
#
# Assuming that the bond has a known continuously componded yield of y, what is the price of the perpetual bond (assume T+0 settlement and zero accrued)?
#
# Use the definition of the semi-annual yield: $y_{sa} = 2 \cdot \left(e^{\frac{y}{2}}-1 \right)$.
#
# You can use following sympy code (implementing Formula 5 from Session 1) as a starting point.

# %%
# import libraries
import sympy as sp

# define fixed rate bond specs as symbolic variables
T = sp.symbols('T')
c = sp.symbols('c')
y = sp.symbols('y')

# define symbolic equation for generic fixed rate bond pv
bond_pv_eq =  1 + (c/2  / (sp.exp(y/2) - 1) - 1 )* (1 - sp.exp(-T*y))
print('Analytic formula for bond_pv:', bond_pv_eq)
display(bond_pv_eq)
# Out:
# Analytic formula for bond_pv: (1 - exp(-T*y))*(c/(2*(exp(y/2) - 1)) - 1) + 1
# (1 - exp(-T*y))*(c/(2*(exp(y/2) - 1)) - 1) + 1

# %%
y_sa = 2 * (sp.exp(y/2) - 1)
P = 100* c / y_sa
print("Price of a fixed perpetial bond: ")
display(P)
# Out:
# Price of a fixed perpetial bond:
# 100*c/(2*exp(y/2) - 2)

# %% [markdown]
# ## b. Perpetual bonds priced "at par"
# For which yield y does the bond trade "at par", i.e. fair value price = $100?

# %%
y_par_solution = sp.solve(sp.Eq(P, 100), y)
print("Yield for Par")
display(y_par_solution[0])
# Out:
# Yield for Par
# 2*log(c/2 + 1)

# %% [markdown]
# ## c. Duration and DV01 for a fixed rate perpetual bond
#
# Compute Duration and DV01 of the perpetual bond.
#
# Use the simpy.diff() function to compute function derivatives.

# %%
dPdy = P.diff(y)
Duration = -(1 / P) * dPdy


print("dP/dy: ")
display(dPdy)
dv01_expr = P * Duration * 0.0001
print("\nDV01 Expression (1bp shift):")
display(dv01_expr)
# Out:
# dP/dy:
# -100*c*exp(y/2)/(2*exp(y/2) - 2)**2
# DV01 Expression (1bp shift):
# 0.01*c*exp(y/2)/(2*exp(y/2) - 2)**2

# %% [markdown]
# ## d. Convexity of a fixed rate perpetual bond
# Compute the convexity of the perpetual bond.

# %%
d2Pdy2 = dPdy.diff(y)
Convexity =  sp.simplify((1 / P) * d2Pdy2)
print("Convexity: ")
display(Convexity)
# Out:
# Convexity:
# (1 + exp(-y/2))*exp(y)/(4*(-2*exp(y/2) + exp(y) + 1))
